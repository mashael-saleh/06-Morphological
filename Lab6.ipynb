# %%
# Task1

erosion = cv2.erode(img, kernel, iterations=1)

dilation = cv2.dilate(img, kernel, iterations=1)

opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)

titles = ['Original Image', 'Erosion', 'Dilation', 'Opening', 'Closing']
images = [img, erosion, dilation, opening, closing]

plt.figure(figsize=(15,8))

for i in range(5):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Task2

erosion_circle = cv2.erode(img, circle_kernel, iterations=1)

dilation_circle = cv2.dilate(img, circle_kernel, iterations=1)

opening_circle = cv2.morphologyEx(img, cv2.MORPH_OPEN, circle_kernel)

closing_circle = cv2.morphologyEx(img, cv2.MORPH_CLOSE, circle_kernel)

titles = ['Original Image', 'Erosion (Circle)', 'Dilation (Circle)',
          'Opening (Circle)', 'Closing (Circle)']

images = [img, erosion_circle, dilation_circle,
          opening_circle, closing_circle]

plt.figure(figsize=(15,8))

for i in range(5):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
#Task3
"""
Difference Between Square and Circular Kernels:
in general, The square kernel is good for general operations and speed,
while the circular kernel gives more natural results for curved objects.
also,
1. Square Kernel:
- Tends to make objects look more square.
- Strong effect in horizontal and vertical directions.
- Can slightly distort circular shapes.

2. Circular Kernel:
- More directionally neutral.
- Produces smoother object boundaries.
- Better for circular or natural objects.

"""
